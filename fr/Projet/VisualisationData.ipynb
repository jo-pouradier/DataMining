# %% [markdown]
# # Visualisation de notre Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import data
df = pd.read_json('./images/ExifDatatest2.json')
df.drop(['image', 'format'], axis=1, inplace=True)
df
# Out:
#          theme  width  height orientation    color_0    color_1    color_2  \
# 0    Exoplanet    960     540     no exif   darkgrey      black      black
# 1    Exoplanet   1600     900     no exif   darkgrey      black       grey
# 2    Exoplanet    960     540     no exif      black      brown  lightgrey
# 3    Exoplanet   1280     720     no exif      black       grey   darkgrey
# 4    Exoplanet   1920    1080     no exif      black      white      brown
# ..         ...    ...     ...         ...        ...        ...        ...
# 712   Voitures   2880    1620     no exif       grey   darkgrey  lightgrey
# 713   Voitures   1280     720     no exif   darkgrey       grey   darkgrey
# 714   Voitures   2880    1620     no exif  lightgrey   darkgrey      black
# 715   Voitures   2880    1620     no exif   darkgrey  lightgrey      black
# 716   Voitures   2880    1620     no exif  lightgrey   darkgrey       grey
#
#        color_3    color_4   red  green  blue
# ...

# %%
# visualise data with seaborn
sns.pairplot(df, height=2.5, hue='theme', y_vars='theme', x_vars=['width', 'height', 'color_0', 'color_1', 'color_2', 'color_3', 'color_4', 'red', 'green', 'blue'], kind='hist')

# %%
sns.pairplot(data=df, kind='hist', hue='theme')

# %%
df_rgb = df[['theme', 'red', 'green', 'blue']]
df_rgb.plot(kind='hist', figsize=(5,5), x='theme', y=['red', 'green', 'blue'], bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_rgb.hist(by='theme', figsize=(10,10), bins=20)
# Out:
# array([[<Axes: title={'center': 'Exoplanet'}>,
#         <Axes: title={'center': 'Moto'}>],
#        [<Axes: title={'center': 'Pokemon2'}>,
#         <Axes: title={'center': 'Voitures'}>]], dtype=object)
